# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset, get_dataset_infos, get_dataset_split_names

# %%
dataset_id = "microsoft/codexglue_method_generation"

get_dataset_infos(dataset_id)
# Out:
# {'microsoft--codexglue_method_generation': DatasetInfo(description='', citation='', homepage='', license='', features=None, post_processed=None, supervised_keys=None, task_templates=None, builder_name='json', config_name='microsoft--codexglue_method_generation', version=0.0.0, splits={'train': {'name': 'train', 'dataset_name': 'microsoft/codexglue_method_generation'}, 'validation': {'name': 'validation', 'dataset_name': 'microsoft/codexglue_method_generation'}, 'test': {'name': 'test', 'dataset_name': 'microsoft/codexglue_method_generation'}}, download_checksums=None, download_size=None, post_processing_size=None, dataset_size=None, size_in_bytes=None)}

# %%
get_dataset_split_names(dataset_id)
# Out:
# ['train', 'validation', 'test']

# %%
# Load the CodeXGLUE dataset
codexglue_dataset = load_dataset("microsoft/codexglue_method_generation")
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\kot_complete\Lib\site-packages\datasets\builder.py:1873, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1866     writer = writer_class(
#    1867         features=writer._features,
#    1868         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    (...)
#    1871         embed_local_files=embed_local_files,
#    1872     )
# -> 1873 writer.write_table(table)
#    1874 num_examples_progress_update += len(table)
#
# File ~\anaconda3\envs\kot_complete\Lib\site-packages\datasets\arrow_writer.py:568, in ArrowWriter.write_table(self, pa_table, writer_batch_size)
# ...

# %%
model_id = "microsoft/phi-1_5"

# Load the Phi-1.5 model and tokenizer
phi_model = AutoModelForCausalLM.from_pretrained(model_id)
phi_tokenizer = AutoTokenizer.from_pretrained(model_id)
